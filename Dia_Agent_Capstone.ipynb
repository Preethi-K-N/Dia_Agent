# %% [markdown]
# __**🏥 Dia-Agent: Privacy-First Clinical Support System**__

# %% [markdown]
# _*Diabetes Care with Human-in-the-Loop Safety*_

# %% [markdown]
# Step 1: Environment Setup & Installation

# %%
# @title 📦 1. Install Dependencies
# Run this cell to install the required packages
# !pip install -q google-adk google-genai python-dotenv pandas

import sys
import os
import asyncio
import pandas as pd

# Validate installation
if "google.adk" in sys.modules:
    print("✅ Google ADK Installed Successfully!")
else:
    print("⚠️ Please restart the kernel if imports fail.")
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ⚠️ Please restart the kernel if imports fail.

# %% [markdown]
# Step 2: Configure Security (API Key)

# %%
import os
# Import the library you installed to read the .env file
from dotenv import load_dotenv 

# 1. Load environment variables from .env file
load_dotenv()

# 2. Try loading from Google Colab Secrets (for Cloud)
try:
    from google.colab import userdata
    colab_key = userdata.get('GOOGLE_API_KEY')
    if colab_key:
        os.environ["GOOGLE_API_KEY"] = colab_key
        print("✅ API Key loaded from Colab Secrets.")
except ImportError:
    pass

# 3. Verify the key is loaded (works for both Local and Cloud)
if os.environ.get("GOOGLE_API_KEY"):
    print("✅ API Key loaded securely from environment.")
else:
    print("⚠️ WARNING: API Key not found. Please check your .env file or Colab Secrets.")
# Out:
# ✅ API Key loaded securely from environment.

# %% [markdown]
# Step 3: Define Clinical Logic (Custom Tools)

# %%
# %%writefile diabetes_tools.py
from google.adk.tools.tool_context import ToolContext

def calculate_clinical_risk(glucose: float, bmi: float, age: int, hypertension: int) -> dict:
    """
    Analyzes patient metrics to determine Diabetes Risk Level.
    Derived from Random Forest analysis of clinical data.
    """
    risk_score = 0
    risk_factors = []

    # Clinical Rules
    if glucose > 125:
        risk_score += 3
        risk_factors.append("High Glucose (>125 mg/dL)")
    elif glucose > 100:
        risk_score += 1
        risk_factors.append("Elevated Glucose")

    if bmi > 30:
        risk_score += 2
        risk_factors.append("Obesity (BMI > 30)")
    
    if hypertension == 1:
        risk_score += 1
        risk_factors.append("Hypertension")

    if age > 45:
        risk_score += 1

    # Risk Classification
    if risk_score >= 3:
        return {
            "risk_level": "HIGH", 
            "score": risk_score, 
            "factors": risk_factors, 
            "advice": "Immediate medical consultation required."
        }
    elif risk_score >= 1:
        return {
            "risk_level": "MODERATE", 
            "score": risk_score, 
            "factors": risk_factors, 
            "advice": "Lifestyle modification recommended."
        }
    else:
        return {
            "risk_level": "LOW", 
            "score": risk_score, 
            "factors": risk_factors, 
            "advice": "Routine checkup schedule."
        }

def notify_doctor_critical(risk_level: str, patient_id: str, tool_context: ToolContext) -> dict:
    """
    Safety Protocol: Pauses execution if Risk is HIGH to get Human Doctor Approval.
    """
    # 1. Auto-approve low/moderate risk
    if risk_level != "HIGH":
        return {"status": "logged", "message": f"Risk is {risk_level}. Logged to internal system."}

    # 2. First Call: Trigger Pause
    if not tool_context.tool_confirmation:
        print(f"\n[SYSTEM ALERT] 🛑 HIGH RISK DETECTED for {patient_id}. Pausing for Doctor Approval...")
        
        tool_context.request_confirmation(
            hint=f"Approve Critical Alert for {patient_id}?",
            payload={"patient_id": patient_id, "risk": risk_level}
        )
        return {"status": "pending", "message": "Waiting for human doctor approval."}

    # 3. Resumed Call: Process Decision
    if tool_context.tool_confirmation.confirmed:
        return {"status": "sent", "message": f"✅ ALERT SENT to Dr. Smith for {patient_id}."}
    else:
        return {"status": "rejected", "message": "❌ Alert cancelled by supervisor."}
# Out:
# Overwriting diabetes_tools.py

# %% [markdown]
# Step 4: The Main Application (Agents & Simulation)

# %% [markdown]
# 4a: Agent Configuration (The Brain)

# %%
# @title 🧠 4a. Define Agents & Pipeline
from google.adk.agents import LlmAgent, SequentialAgent
from google.adk.models.google_llm import Gemini
from google.adk.apps.app import App, ResumabilityConfig
from google.adk.plugins.logging_plugin import LoggingPlugin
from google.genai import types

# Import tools
from diabetes_tools import calculate_clinical_risk, notify_doctor_critical

# Configuration
MODEL_NAME = "gemini-2.0-flash"
retry_config = types.HttpRetryOptions(attempts=3)

# --- AGENT 1: Clinical Analyst ---
analyst_agent = LlmAgent(
    name="ClinicalAnalyst",
    model=Gemini(model=MODEL_NAME, retry_options=retry_config),
    instruction="""You are an expert Clinical Analyst.
    1. Analyze patient metrics.
    2. Use `calculate_clinical_risk`.
    3. CRITICAL: If risk is found, you MUST use `notify_doctor_critical`.
    4. Output a structured clinical summary.""",
    tools=[calculate_clinical_risk, notify_doctor_critical],
    output_key="clinical_summary"
)

# --- AGENT 2: Lifestyle Coach ---
coach_agent = LlmAgent(
    name="LifestyleCoach",
    model=Gemini(model=MODEL_NAME, retry_options=retry_config),
    instruction="""You are a Lifestyle Coach.
    1. Read the clinical summary: {clinical_summary}
    2. Use `load_memory` to check patient preferences.
    3. Create a plan that respects their preferences AND addresses medical risk.""",
    # Note: load_memory tool is added by the Runner automatically if we configure memory service
    tools=[] 
)

# --- PIPELINE ---
dia_pipeline = SequentialAgent(
    name="DiaCarePipeline",
    sub_agents=[analyst_agent, coach_agent]
)

# --- APP WRAPPER ---
dia_app = App(
    name="DiaAgent",
    root_agent=dia_pipeline,
    resumability_config=ResumabilityConfig(is_resumable=True),
    plugins=[LoggingPlugin()]
)

print("✅ Agents & Pipeline Configured.")
# Out:
# ✅ Agents & Pipeline Configured.
# C:\Users\preet\AppData\Local\Temp\ipykernel_24052\3877780493.py:50: UserWarning: [EXPERIMENTAL] ResumabilityConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   resumability_config=ResumabilityConfig(is_resumable=True),

# %% [markdown]
# 4b: Initialize Services (The Engine)

# %%
# @title ⚙️ 4b. Initialize Runner & Services
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.memory import InMemoryMemoryService
from google.adk.tools import load_memory

# Initialize Services
session_service = InMemorySessionService()
memory_service = InMemoryMemoryService()

# Initialize Runner
runner = Runner(
    app=dia_app,
    session_service=session_service,
    memory_service=memory_service
)

# Add load_memory tool to coach (Dynamic addition)
coach_agent.tools.append(load_memory)

print("✅ Engine Started. Runner is ready.")
# Out:
# App name mismatch detected. The runner is configured with app name "DiaCareApp", but the root agent was loaded from "E:\D_volume\Preethi\OneDrive\Desktop\desktopfiles\Kaggle Agentic AI 5 day course\diabetes_capstone\.venv\Lib\site-packages\google\adk\agents", which implies app name "agents".
# ✅ Engine Started. Runner is ready.

# %% [markdown]
# 4c: Seeding Memory (The Setup)

# %%
# @title 💾 4c. Seed Long-Term Memory
# We simulate a past visit to teach the agent about the patient
history_session_id = "past_visit_001"
user_id = "patient_001"

# 1. Create Session
await session_service.create_session(
    app_name="DiaCareApp", user_id=user_id, session_id=history_session_id
)

# 2. Input History
history_input = "Patient Update: Glucose 90. Note: Patient is strictly VEGAN and enjoys SWIMMING."
print(f"📝 Injecting History: {history_input}")

async for event in runner.run_async(
    user_id=user_id, 
    session_id=history_session_id, 
    new_message=types.Content(role="user", parts=[types.Part(text=history_input)])
):
    pass 

# 3. Save to Memory
history_session = await session_service.get_session(
    app_name="DiaCareApp", user_id=user_id, session_id=history_session_id
)
await memory_service.add_session_to_memory(history_session)
print("✅ Patient History saved to Memory.")
# Out:
# 📝 Injecting History: Patient Update: Glucose 90. Note: Patient is strictly VEGAN and enjoys SWIMMING.
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-8e4b44cf-d1d1-478f-88b7-fb981a37e2d4
# [logging_plugin]    Session ID: past_visit_001
# [logging_plugin]    User ID: patient_001
# [logging_plugin]    App Name: DiaCareApp
# [logging_plugin]    Root Agent: DiaCarePipeline
# [logging_plugin]    User Content: text: 'Patient Update: Glucose 90. Note: Patient is strictly VEGAN and enjoys SWIMMING.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-8e4b44cf-d1d1-478f-88b7-fb981a37e2d4
# [logging_plugin]    Starting Agent: DiaCarePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: DiaCarePipeline
# [logging_plugin]    Invocation ID: e-8e4b44cf-d1d1-478f-88b7-fb981a37e2d4
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7bcbf5b4-4218-4b8c-b7a4-8827980777fa
# [logging_plugin]    Author: DiaCarePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ClinicalAnalyst
# [logging_plugin]    Invocation ID: e-8e4b44cf-d1d1-478f-88b7-fb981a37e2d4
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    System Instruction: 'You are an expert Clinical Analyst.
#     1. Analyze patient metrics.
#     2. Use `calculate_clinical_risk`.
#     3. CRITICAL: If risk is found, you MUST use `notify_doctor_critical`.
#     4. Output a stru...'
# [logging_plugin]    Available Tools: ['calculate_clinical_risk', 'notify_doctor_critical']
# e:\D_volume\Preethi\OneDrive\Desktop\desktopfiles\Kaggle Agentic AI 5 day course\diabetes_capstone\.venv\Lib\site-packages\google\adk\agents\sequential_agent.py:72: UserWarning: [EXPERIMENTAL] SequentialAgentState: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   agent_state = SequentialAgentState(current_sub_agent=sub_agent.name)
# e:\D_volume\Preethi\OneDrive\Desktop\desktopfiles\Kaggle Agentic AI 5 day course\diabetes_capstone\.venv\Lib\site-packages\google\adk\utils\feature_decorator.py:87: UserWarning: [EXPERIMENTAL] BaseAgentState: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   return orig_init(self, *args, **kwargs)
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    Content: text: 'Okay, I will analyze the patient's risk factors and provide a clinical summary. I need the patient's BMI, age, and hypertension status.'
# [logging_plugin]    Token Usage - Input: 173, Output: 32
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 958d17c7-2bb9-4e49-990f-786d81d487e6
# [logging_plugin]    Author: ClinicalAnalyst
# [logging_plugin]    Content: text: 'Okay, I will analyze the patient's risk factors and provide a clinical summary. I need the patient's BMI, age, and hypertension status.'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: be9ea53f-0a29-4088-ae73-d07b9154b21d
# [logging_plugin]    Author: ClinicalAnalyst
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ClinicalAnalyst
# [logging_plugin]    Invocation ID: e-8e4b44cf-d1d1-478f-88b7-fb981a37e2d4
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e960bd7c-357b-4eaa-af45-09c3f80d8926
# [logging_plugin]    Author: DiaCarePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LifestyleCoach
# [logging_plugin]    Invocation ID: e-8e4b44cf-d1d1-478f-88b7-fb981a37e2d4
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: LifestyleCoach
# [logging_plugin]    System Instruction: 'You are a Lifestyle Coach.
#     1. Read the clinical summary: Okay, I will analyze the patient's risk factors and provide a clinical summary. I need the patient's BMI, age, and hypertension status.
#
#   ...'
# [logging_plugin]    Available Tools: ['load_memory']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LifestyleCoach
# [logging_plugin]    Content: text: 'Okay, I need the patient's BMI, age, and hypertension status to provide a clinical summary. Once I have that, I will use `load_memory` to check patient preferences and then create a plan that respects...'
# [logging_plugin]    Token Usage - Input: 308, Output: 53
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 3ebb6b0a-3497-4c5c-84cf-a0b75c20ab5f
# [logging_plugin]    Author: LifestyleCoach
# [logging_plugin]    Content: text: 'Okay, I need the patient's BMI, age, and hypertension status to provide a clinical summary. Once I have that, I will use `load_memory` to check patient preferences and then create a plan that respects...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 573d329b-8bd5-4c75-b290-7249a0d7c6a6
# [logging_plugin]    Author: LifestyleCoach
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LifestyleCoach
# [logging_plugin]    Invocation ID: e-8e4b44cf-d1d1-478f-88b7-fb981a37e2d4
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: b06b9609-7f50-4202-bfbd-973548ae912d
# [logging_plugin]    Author: DiaCarePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: DiaCarePipeline
# [logging_plugin]    Invocation ID: e-8e4b44cf-d1d1-478f-88b7-fb981a37e2d4
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-8e4b44cf-d1d1-478f-88b7-fb981a37e2d4
# [logging_plugin]    Final Agent: DiaCarePipeline
# ✅ Patient History saved to Memory.

# %% [markdown]
# 4d: Live Analysis & Pause (The Conflict)

# %%
# @title 🚨 4d. Live Diagnosis (Triggers Pause)
# High Risk Data
user_query = "Patient ID: 001. New Vitals: Glucose 145 mg/dL, BMI 31.0, Age 55, Hypertension: Yes."
session_id = "live_session_01"

print(f"👤 [Input]: {user_query}")
print("⏳ Agent is thinking...\n")

# Create Session
await session_service.create_session(
    app_name="DiaCareApp", user_id=user_id, session_id=session_id
)

# Variable to store the pause state for the next cell
pause_state = {} 

async for event in runner.run_async(
    user_id=user_id, 
    session_id=session_id, 
    new_message=types.Content(role="user", parts=[types.Part(text=user_query)])
):
    # Pretty Print the Agent's Thought Process
    if event.is_final_response() and event.content:
        print(f"\n🤖 [Analyst]: {event.content.parts[0].text}")
    
    # Detect Pause Request
    if event.content and event.content.parts:
        for part in event.content.parts:
            if part.function_call and part.function_call.name == "adk_request_confirmation":
                print("\n" + "="*50)
                print("🛑 SYSTEM PAUSED: Doctor Approval Required")
                print(f"   Reason: High Risk Detected for {user_id}")
                print("="*50 + "\n")
                # Save state for the next cell
                pause_state = {
                    "approval_id": part.function_call.id, 
                    "inv_id": event.invocation_id
                }
# Out:
# 👤 [Input]: Patient ID: 001. New Vitals: Glucose 145 mg/dL, BMI 31.0, Age 55, Hypertension: Yes.
# ⏳ Agent is thinking...
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin]    Session ID: live_session_01
# [logging_plugin]    User ID: patient_001
# [logging_plugin]    App Name: DiaCareApp
# [logging_plugin]    Root Agent: DiaCarePipeline
# [logging_plugin]    User Content: text: 'Patient ID: 001. New Vitals: Glucose 145 mg/dL, BMI 31.0, Age 55, Hypertension: Yes.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin]    Starting Agent: DiaCarePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: DiaCarePipeline
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ea153915-5897-48ba-87be-62308b756fd3
# [logging_plugin]    Author: DiaCarePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ClinicalAnalyst
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    System Instruction: 'You are an expert Clinical Analyst.
#     1. Analyze patient metrics.
#     2. Use `calculate_clinical_risk`.
#     3. CRITICAL: If risk is found, you MUST use `notify_doctor_critical`.
#     4. Output a stru...'
# [logging_plugin]    Available Tools: ['calculate_clinical_risk', 'notify_doctor_critical']
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    Content: function_call: calculate_clinical_risk
# [logging_plugin]    Token Usage - Input: 189, Output: 14
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 60bf9e19-100f-43d9-9d5a-c3af083a4356
# [logging_plugin]    Author: ClinicalAnalyst
# [logging_plugin]    Content: function_call: calculate_clinical_risk
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['calculate_clinical_risk']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: calculate_clinical_risk
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    Function Call ID: adk-1f1994a7-b135-493e-8ee5-9bbeac4b7945
# [logging_plugin]    Arguments: {'glucose': 145, 'bmi': 31, 'hypertension': 1, 'age': 55}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: calculate_clinical_risk
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    Function Call ID: adk-1f1994a7-b135-493e-8ee5-9bbeac4b7945
# [logging_plugin]    Result: {'risk_level': 'HIGH', 'score': 7, 'factors': ['High Glucose (>125 mg/dL)', 'Obesity (BMI > 30)', 'Hypertension'], 'advice': 'Immediate medical consultation required.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 5b42acba-83f7-464c-b253-d77a0c3be506
# [logging_plugin]    Author: ClinicalAnalyst
# [logging_plugin]    Content: function_response: calculate_clinical_risk
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['calculate_clinical_risk']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    System Instruction: 'You are an expert Clinical Analyst.
#     1. Analyze patient metrics.
#     2. Use `calculate_clinical_risk`.
#     3. CRITICAL: If risk is found, you MUST use `notify_doctor_critical`.
#     4. Output a stru...'
# [logging_plugin]    Available Tools: ['calculate_clinical_risk', 'notify_doctor_critical']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    Content: text: 'Patient 001 presents with a HIGH risk level based on the following factors: High Glucose (>125 mg/dL), Obesity (BMI > 30), and Hypertension. Immediate medical consultation is required.' | function_call: notify_doctor_critical
# [logging_plugin]    Token Usage - Input: 241, Output: 60
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: acba3552-e299-412f-b435-5e6b4745b5bd
# [logging_plugin]    Author: ClinicalAnalyst
# [logging_plugin]    Content: text: 'Patient 001 presents with a HIGH risk level based on the following factors: High Glucose (>125 mg/dL), Obesity (BMI > 30), and Hypertension. Immediate medical consultation is required.' | function_call: notify_doctor_critical
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['notify_doctor_critical']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: notify_doctor_critical
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    Function Call ID: adk-a05ce544-a2f3-4a64-840f-c9d1b37226c4
# [logging_plugin]    Arguments: {'risk_level': 'HIGH', 'patient_id': '001'}
#
# [SYSTEM ALERT] 🛑 HIGH RISK DETECTED for 001. Pausing for Doctor Approval...
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: notify_doctor_critical
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    Function Call ID: adk-a05ce544-a2f3-4a64-840f-c9d1b37226c4
# [logging_plugin]    Result: {'status': 'pending', 'message': 'Waiting for human doctor approval.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: fb6855ce-b325-4e99-b1f7-198e06ae2486
# [logging_plugin]    Author: ClinicalAnalyst
# [logging_plugin]    Content: function_call: adk_request_confirmation
# [logging_plugin]    Final Response: True
# [logging_plugin]    Function Calls: ['adk_request_confirmation']
# [logging_plugin]    Long Running Tools: ['adk-126437a9-c7b7-4536-ae74-a217962719a5']
#
# 🤖 [Analyst]: None
#
# ==================================================
# 🛑 SYSTEM PAUSED: Doctor Approval Required
#    Reason: High Risk Detected for patient_001
# ==================================================
#
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 24ac3f75-8463-4ca4-9921-0e6d3ec85beb
# [logging_plugin]    Author: ClinicalAnalyst
# [logging_plugin]    Content: function_response: notify_doctor_critical
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['notify_doctor_critical']
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ClinicalAnalyst
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: DiaCarePipeline
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin]    Final Agent: DiaCarePipeline
# e:\D_volume\Preethi\OneDrive\Desktop\desktopfiles\Kaggle Agentic AI 5 day course\diabetes_capstone\.venv\Lib\site-packages\google\adk\tools\tool_context.py:92: UserWarning: [EXPERIMENTAL] ToolConfirmation: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   ToolConfirmation(

# %% [markdown]
# Human Approval (The Resolution)

# %%
# @title 👨‍⚕️ 4e. Doctor Approval & Resume
if not pause_state:
    print("⚠️ No pause detected. Run Cell 4d first.")
else:
    print("👨‍⚕️ Doctor clicks [APPROVE] button on dashboard...")
    print("▶️  Resuming Agent Workflow...\n")
    
    # Create Approval Signal
    confirmation = types.FunctionResponse(
        id=pause_state["approval_id"], 
        name="adk_request_confirmation", 
        response={"confirmed": True} 
    )
    
    # Resume
    async for event in runner.run_async(
        user_id=user_id,
        session_id=session_id,
        new_message=types.Content(role="user", parts=[types.Part(function_response=confirmation)]),
        invocation_id=pause_state["inv_id"] # This connects back to the paused state
    ):
         if event.is_final_response() and event.content:
             print(f"\n🤖 [Coach]: {event.content.parts[0].text}")

    print("\n✅ Case Closed.")
# Out:
# 👨‍⚕️ Doctor clicks [APPROVE] button on dashboard...
# ▶️  Resuming Agent Workflow...
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin]    Session ID: live_session_01
# [logging_plugin]    User ID: patient_001
# [logging_plugin]    App Name: DiaCareApp
# [logging_plugin]    Root Agent: DiaCarePipeline
# [logging_plugin]    User Content: function_response: adk_request_confirmation
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin]    Starting Agent: DiaCarePipeline
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: DiaCarePipeline
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ClinicalAnalyst
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: notify_doctor_critical
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    Function Call ID: adk-a05ce544-a2f3-4a64-840f-c9d1b37226c4
# [logging_plugin]    Arguments: {'risk_level': 'HIGH', 'patient_id': '001'}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: notify_doctor_critical
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    Function Call ID: adk-a05ce544-a2f3-4a64-840f-c9d1b37226c4
# [logging_plugin]    Result: {'status': 'sent', 'message': '✅ ALERT SENT to Dr. Smith for 001.'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 1c33366c-7a15-4826-99a3-6c203d673f8b
# [logging_plugin]    Author: ClinicalAnalyst
# [logging_plugin]    Content: function_response: notify_doctor_critical
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['notify_doctor_critical']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    System Instruction: 'You are an expert Clinical Analyst.
#     1. Analyze patient metrics.
#     2. Use `calculate_clinical_risk`.
#     3. CRITICAL: If risk is found, you MUST use `notify_doctor_critical`.
#     4. Output a stru...'
# [logging_plugin]    Available Tools: ['calculate_clinical_risk', 'notify_doctor_critical']
# e:\D_volume\Preethi\OneDrive\Desktop\desktopfiles\Kaggle Agentic AI 5 day course\diabetes_capstone\.venv\Lib\site-packages\google\adk\agents\invocation_context.py:302: UserWarning: [EXPERIMENTAL] BaseAgentState: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   self.agent_states[event.author] = BaseAgentState()
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: ClinicalAnalyst
# [logging_plugin]    Content: text: 'Clinical Summary:
#
# Patient ID: 001
# Risk Level: HIGH
# Factors: High Glucose, Obesity, Hypertension
# Advice: Immediate medical consultation required.
# Notification: ALERT SENT to Dr. Smith.'
# [logging_plugin]    Token Usage - Input: 322, Output: 44
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 78e00a3b-cdf3-4a71-a318-af66df673a46
# [logging_plugin]    Author: ClinicalAnalyst
# [logging_plugin]    Content: text: 'Clinical Summary:
#
# Patient ID: 001
# Risk Level: HIGH
# Factors: High Glucose, Obesity, Hypertension
# Advice: Immediate medical consultation required.
# Notification: ALERT SENT to Dr. Smith.'
# [logging_plugin]    Final Response: True
#
# 🤖 [Coach]: Clinical Summary:
#
# Patient ID: 001
# Risk Level: HIGH
# Factors: High Glucose, Obesity, Hypertension
# Advice: Immediate medical consultation required.
# Notification: ALERT SENT to Dr. Smith.
#
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ca627e35-cf68-4b6e-892b-152183fe7303
# [logging_plugin]    Author: ClinicalAnalyst
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ClinicalAnalyst
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 73575267-0c05-4c7a-93fb-6d8ccf1fde99
# [logging_plugin]    Author: DiaCarePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: LifestyleCoach
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: LifestyleCoach
# [logging_plugin]    System Instruction: 'You are a Lifestyle Coach.
#     1. Read the clinical summary: Clinical Summary:
#
# Patient ID: 001
# Risk Level: HIGH
# Factors: High Glucose, Obesity, Hypertension
# Advice: Immediate medical consultation req...'
# [logging_plugin]    Available Tools: ['load_memory']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LifestyleCoach
# [logging_plugin]    Content: text: 'Okay, I have the clinical summary. Now I need to check patient preferences before creating a plan.' | function_call: load_memory
# [logging_plugin]    Token Usage - Input: 630, Output: 31
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 01fde017-583a-49b6-b7ca-0c6b1ecf93ac
# [logging_plugin]    Author: LifestyleCoach
# [logging_plugin]    Content: text: 'Okay, I have the clinical summary. Now I need to check patient preferences before creating a plan.' | function_call: load_memory
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['load_memory']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: load_memory
# [logging_plugin]    Agent: LifestyleCoach
# [logging_plugin]    Function Call ID: adk-6db399e2-ad69-40e0-853a-8f0209bd9484
# [logging_plugin]    Arguments: {'query': 'Patient 001 preferences'}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: load_memory
# [logging_plugin]    Agent: LifestyleCoach
# [logging_plugin]    Function Call ID: adk-6db399e2-ad69-40e0-853a-8f0209bd9484
# [logging_plugin]    Result: memories=[MemoryEntry(content=Content(
#   parts=[
#     Part(
#       text='Patient Update: Glucose 90. Note: Patient is strictly VEGAN and enjoys SWIMMING.'
#     ),
#   ],
#   role='user'
# ), custom_metadata={}, id=None, author='user', timestamp='2025-11-21T14:10:54.345286'), MemoryEntry(content=Content(
#   pa...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9cb19ad1-1520-4dff-9d7f-55fd46516219
# [logging_plugin]    Author: LifestyleCoach
# [logging_plugin]    Content: function_response: load_memory
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['load_memory']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: LifestyleCoach
# [logging_plugin]    System Instruction: 'You are a Lifestyle Coach.
#     1. Read the clinical summary: Clinical Summary:
#
# Patient ID: 001
# Risk Level: HIGH
# Factors: High Glucose, Obesity, Hypertension
# Advice: Immediate medical consultation req...'
# [logging_plugin]    Available Tools: ['load_memory']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: LifestyleCoach
# [logging_plugin]    Content: text: 'Okay, I have the patient's preferences. They are vegan and enjoy swimming.
#
# Here's a plan for Patient 001, keeping in mind their high risk level, vegan preference, and enjoyment of swimming:
#
# **Immedi...'
# [logging_plugin]    Token Usage - Input: 885, Output: 695
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 24cfc0d7-4c1c-41e5-b26a-16e33d535290
# [logging_plugin]    Author: LifestyleCoach
# [logging_plugin]    Content: text: 'Okay, I have the patient's preferences. They are vegan and enjoy swimming.
#
# Here's a plan for Patient 001, keeping in mind their high risk level, vegan preference, and enjoyment of swimming:
#
# **Immedi...'
# [logging_plugin]    Final Response: True
#
# 🤖 [Coach]: Okay, I have the patient's preferences. They are vegan and enjoy swimming.
#
# Here's a plan for Patient 001, keeping in mind their high risk level, vegan preference, and enjoyment of swimming:
#
# **Immediate Action:**
#
# *   The clinical summary advises immediate medical consultation. This is the top priority. Ensure the patient follows up with Dr. Smith as soon as possible.
#
# **Lifestyle Plan (to be implemented alongside medical treatment):**
#
# 1.  **Diet:**
#     *   **Focus:** Lowering glucose levels, promoting weight loss, and managing hypertension through diet.
#     *   **Specifics:**
#         *   Work with a registered dietitian experienced in vegan diets to create a meal plan.
#         *   Emphasize whole, unprocessed vegan foods: vegetables, fruits (in moderation due to glucose), legumes, and whole grains.
#         *   Limit processed vegan foods, sugary drinks, and refined carbohydrates, which can spike glucose levels.
#         *   Focus on incorporating foods known to help manage blood pressure, such as leafy green vegetables, berries, and beetroot.
#         *   Ensure adequate protein intake through sources like lentils, beans, tofu, and tempeh.
#         *   Consider a consultation with a registered dietitian to ensure proper nutrient intake on a vegan diet, especially regarding vitamin B12, iron, and omega-3 fatty acids.
#
# 2.  **Exercise:**
#     *   **Focus:** Weight loss, improving insulin sensitivity, and lowering blood pressure.
#     *   **Specifics:**
#         *   Swimming: Encourage regular swimming sessions. Start with 30 minutes, 3 times a week, and gradually increase duration and frequency. Swimming is a great low-impact exercise.
#         *   Additional Activity: Incorporate other forms of moderate-intensity exercise, such as brisk walking or cycling, on days they don't swim.
#         *   Strength Training: Add light strength training exercises (bodyweight exercises or light weights) 2-3 times per week to build muscle mass, which can help improve metabolism and glucose control.
#
# 3.  **Monitoring:**
#     *   **Focus:** Tracking progress and making adjustments as needed.
#     *   **Specifics:**
#         *   Regularly monitor blood glucose levels as directed by their doctor.
#         *   Track weight and blood pressure.
#         *   Keep a food diary to monitor dietary intake and identify potential triggers for glucose spikes.
#
# 4.  **Stress Management:**
#     *   **Focus:** Reducing stress levels, which can impact blood glucose and blood pressure.
#     *   **Specifics:**
#         *   Encourage relaxation techniques like deep breathing exercises, meditation, or yoga.
#         *   Ensure adequate sleep (7-8 hours per night).
#
# **Important Considerations:**
#
# *   **Medical Supervision:** This plan is a supplement to, not a replacement for, medical care. The patient MUST follow their doctor's recommendations and take prescribed medications as directed.
# *   **Gradual Changes:** Implement changes gradually to improve adherence and avoid feeling overwhelmed.
# *   **Education:** Provide the patient with resources about managing diabetes, hypertension, and obesity through lifestyle modifications.
# *   **Support:** Encourage the patient to seek support from family, friends, or a support group.
#
# I will document this plan.
#
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4f27a7b0-9a46-4d7a-a0d1-5132738431ff
# [logging_plugin]    Author: LifestyleCoach
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: LifestyleCoach
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0b8a972b-dfc8-45e1-a9b4-fcfcfec5ac44
# [logging_plugin]    Author: DiaCarePipeline
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: DiaCarePipeline
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-1f487ccd-00bb-4d73-8d2c-20ff2b58350b
# [logging_plugin]    Final Agent: DiaCarePipeline
#
# ✅ Case Closed.
